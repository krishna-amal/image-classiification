# %%
import cv2

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

gen_train = ImageDataGenerator(rescale = 1/255, shear_range = 0.2, zoom_range = 0.2, 
                               brightness_range = (0.1, 0.5), horizontal_flip=True)

train_data = gen_train.flow_from_directory("garbage_classification",
                                           target_size = (224, 224), batch_size = 32, class_mode="categorical")
# Out:
# Found 305 images belonging to 3 classes.

# %%
# let's create a model
# here i'm going to use VGG16 model's parameter to solve this problem

from tensorflow.keras.applications.vgg16 import VGG16

# here i'm going to take input shape, weights and bias from imagenet and include top False means
# i want to add input, flatten and output layer by my self

vgg16 = VGG16(input_shape = (224, 224, 3), weights = "imagenet", include_top = False)

# %%
# now vgg16 weights are already train so i don't want to train that weights again
# so let's make trainable = False

for layer in vgg16.layers:
  layer.trainable = False

# %%
# let's add flatten layer or let's connect VGG16 with our own flatten layer

from tensorflow.keras import layers

x = layers.Flatten()(vgg16.output)

# %%
# now let's add output layers or prediction layer

prediction = layers.Dense(units = 3, activation="softmax")(x)

# creating a model object

model = tf.keras.models.Model(inputs = vgg16.input, outputs=prediction)
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_3 (Flatten)         (None, 25088)             0
#
#  dense_5 (Dense)             (None, 3)                 75267
#
# =================================================================
# Total params: 14,789,955
# Trainable params: 75,267
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# now let's compile the model

model.compile(optimizer="adam", loss="categorical_crossentropy", metrics =["accuracy"])

result = model.fit_generator(train_data, epochs = 10, steps_per_epoch=len(train_data))
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_42668\1669616798.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   result = model.fit_generator(train_data, epochs = 10, steps_per_epoch=len(train_data))
# Epoch 1/10
# 10/10 [==============================] - 63s 6s/step - loss: 1.4936 - accuracy: 0.3541
# Epoch 2/10
# 10/10 [==============================] - 88s 9s/step - loss: 0.9111 - accuracy: 0.5574
# Epoch 3/10
# 10/10 [==============================] - 86s 9s/step - loss: 0.6427 - accuracy: 0.6951
# Epoch 4/10
# 10/10 [==============================] - 107s 10s/step - loss: 0.6042 - accuracy: 0.7443
# Epoch 5/10
# 10/10 [==============================] - 107s 11s/step - loss: 0.5172 - accuracy: 0.7967
# Epoch 6/10
# 10/10 [==============================] - 102s 10s/step - loss: 0.4067 - accuracy: 0.8623
# Epoch 7/10
# 10/10 [==============================] - 68s 7s/step - loss: 0.4193 - accuracy: 0.8361
# Epoch 8/10
# 10/10 [==============================] - 64s 6s/step - loss: 0.4463 - accuracy: 0.8164
# Epoch 9/10
# 10/10 [==============================] - 63s 6s/step - loss: 0.3797 - accuracy: 0.8623
# Epoch 10/10
# 10/10 [==============================] - 70s 7s/step - loss: 0.3320 - accuracy: 0.9049

# %%
from tensorflow.keras.preprocessing import image
output_class = ["batteries", "cardboard","cloth"]
def waste_prediction(new_image):
  test_image = image.load_img(new_image, target_size = (224,224))
  plt.axis("off")
  plt.imshow(test_image)
  plt.show()
 
  test_image = image.img_to_array(test_image) / 255
  test_image = np.expand_dims(test_image, axis=0)

  predicted_array = model.predict(test_image)
  predicted_value = output_class[np.argmax(predicted_array)]
  predicted_accuracy = round(np.max(predicted_array) * 100, 2)

  print("Your waste material is ", predicted_value, " with ", predicted_accuracy, " % accuracy")

# %%
waste_prediction("battery.jpg")
# Out:
# 1/1 [==============================] - 0s 175ms/step
# Your waste material is  batteries  with  100.0  % accuracy

# %%
waste_prediction("bespoke-cardboard-boxes.jpg")
# Out:
# 1/1 [==============================] - 0s 173ms/step
# Your waste material is  cardboard  with  99.76  % accuracy

# %%
waste_prediction("cloth.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_50004\544734455.py in <module>
# ----> 1 waste_prediction("cloth.jpg")
#
# ~\AppData\Local\Temp\ipykernel_50004\2431026312.py in waste_prediction(new_image)
#      10   test_image = np.expand_dims(test_image, axis=0)
#      11
# ---> 12   predicted_array = model.predict(test_image)
#      13   predicted_value = output_class[np.argmax(predicted_array)]
#      14   predicted_accuracy = round(np.max(predicted_array) * 100, 2)
#
# NameError: name 'model' is not defined

# %%
from keras.models import load_model
#model.save("waste.h5")
loaded_model = load_model("waste.h5")

# %%
new_image="cloth.jpg"

# %%
test_image = image.load_img(new_image, target_size = (224,224))
test_image = image.img_to_array(test_image) / 255
test_image = np.expand_dims(test_image, axis=0)

predicted_array = loaded_model.predict(test_image)
predicted_value = output_class[np.argmax(predicted_array)]
print("predicted_array:",predicted_array)
print("predicted_value:",predicted_value)
# Out:
# 1/1 [==============================] - 0s 175ms/step
# predicted_array: [[0.08153319 0.17211632 0.7463505 ]]
# predicted_value: cloth

# %%
key = cv2. waitKey(1)
webcam = cv2.VideoCapture(0)
while True:
    try:
        check, frame = webcam.read()
        #print(check) #prints true as long as the webcam is running
        #print(frame) #prints matrix values of each framecd 
        cv2.imshow("Capturing", frame)
        test_image = image.load_img(frame, target_size = (224,224))
        test_image = image.img_to_array(test_image) / 255
        test_image = np.expand_dims(test_image, axis=0)

        predicted_array = model.predict(test_image)
        predicted_value = output_class[np.argmax(predicted_array)]
        print("predicted_array:",predicted_array)
        print("predicted_value:",predicted_value)
        key = cv2.waitKey(1)
#         if key == ord('s'): 
#             cv2.imwrite(filename='saved_img.jpg', img=frame)
#             webcam.release()
#             img_new = cv2.imread('saved_img.jpg')
#             img_new = cv2.imshow("Captured Image", img_new)
#             cv2.waitKey(1650)
#             cv2.destroyAllWindows()

            #break
        if key == ord('q'):
            print("Turning off camera.")
            webcam.release()
            print("Camera off.")
            print("Program ended.")
            cv2.destroyAllWindows()
            
            break
        
    except(KeyboardInterrupt):
        print("Turning off camera.")
        webcam.release()
        print("Camera off.")
        print("Program ended.")
        cv2.destroyAllWindows()
        break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_50004\1309668382.py in <module>
#       7         #print(frame) #prints matrix values of each framecd
#       8         cv2.imshow("Capturing", frame)
# ----> 9         test_image = image.load_img(frame, target_size = (224,224))
#      10         test_image = image.img_to_array(test_image) / 255
#      11         test_image = np.expand_dims(test_image, axis=0)
#
# ~\anaconda3\lib\site-packages\keras\utils\image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
# --> 425         raise TypeError(
#     426             f"path should be path-like or io.BytesIO, not {type(path)}"
#     427         )
#
# TypeError: path should be path-like or io.BytesIO, not <class 'numpy.ndarray'>
